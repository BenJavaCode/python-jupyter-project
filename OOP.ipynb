# %%
# Classes, inharentence, super, self
# instance attributes, class attributes
# getters and setters, properties, encapsulation
# private attributes and methods

# %%
#The Pythonic way to introduce attributes is to make them public!

# %%
#Inharentence
class Jedi:
    force = 'The force is with me' #class attribute
    
    def __init__(self, name, clan, midi_clorian_count): #self is the 'pointer' to its instance
        self.name = name #instance attribute
        self.clan = clan
        self.midi_clorian_count = midi_clorian_count # not needed by users of the class, therefore private
    
    def use_the_force(self, context):
        print(f'I {self.name} use the force for {context}')
    
    # We will define it as a private attribute with the corresponding property,
    # if and only if we have to do some checks or transformation of the data.
    @property #A method which is used for getting a value is decorated with "@property"
    def midi_clorian_count(self):
        return self.__midi_clorian_count #double underscore is name mangling
    
    @midi_clorian_count.setter #he method which has to function as the setter is decorated with "@x.setter".
    def midi_clorian_count(self, inp):
        try:
            int(inp)
            if int(inp) > 20000:
                self.__midi_clorian_count = 20000
            elif int(inp) < 0:
                self.__midi_clorian_count = 0
            else:
                self.__midi_clorian_count = int(inp)
        except(ValueError):
            print('medi_clorian_count needs to be a number')
    
    def __str__(self):
        return(f'My name is {self.name}, my clan is {self.clan}, my medi clorian count is {self.midi_clorian_count}')
            
        
    
class Sith(Jedi):
    
    def __init__(self, name, clan, m_d_count, secret_name):
        super().__init__(name, clan, m_d_count)
        self.__secret_name = secret_name # private attribute
    
    def use_the_force(self, context = 'evil'):
        self.__secret_force()
        return super().use_the_force(context)
    
    def __secret_force(self):
        print(f'You will be unstoppable once you learn to listen to your emotions {self.__secret_name}!')

# %%
sith = Sith('Darth Maul', 'Siths', 2000, 'Claus Bóve')

# %%
sith.use_the_force()
print(sith)
sith.midi_clorian_count = '20000'
sith.name = 'Darth Vader'

sith.midi_clorian_count
print(sith)
# Out:
# You will be unstoppable once you learn to listen to your emotions Claus Bóve!
# I Darth Maul use the force for evil
# My name is Darth Maul, my clan is Siths, my medi clorian count is 2000
# My name is Darth Vader, my clan is Siths, my medi clorian count is 20000

# %%
#Accesing private attributes and methods
sith._Sith__secret_name = 'Benjabob Bob Bendsen'
print(sith._Sith__secret_name)
sith._Sith__secret_force()
# Out:
# Benjabob Bob Bendsen
# You will be unstoppable once you learn to listen to your emotions Benjabob Bob Bendsen!

# %%
# Ugly way for getters and setter
class P:

    def __init__(self,x):
        self.__set_x(x)

    def __get_x(self):
        return self.__x

    def __set_x(self, x):
        if x < 0:
            self.__x = 0
        elif x > 1000:
            self.__x = 1000
        else:
            self.__x = x
            
    x = property(__get_x, __set_x) #assign methods to class atribute..

p = P(10)

p.x = 15
p.x
# Out:
# 15

# %%
# Self
'''self represents the instance of the class. 
By using the “self” keyword we can access the attributes and methods of the class in python. 
It binds the attributes with the given arguments.

The reason you need to use self. 
is because Python does not use the @ syntax to refer to instance attributes.
Python decided to do methods in a way that makes the instance to which the method belongs be passed automatically,
but not received automatically: the first parameter of methods is the instance the method is called on'''

# %%
#built in decorators for classes

class Carrot:
    
    def __init__(self, color, taste):
        self._color = color
        self.taste = taste
    
    @property
    def color(self):
        return self._color
    
    @color.setter
    def color(self, inp):
        if isinstance(inp, str):
            self._color = inp
        else:
            print('That cant possible be a color, so now its just orange now')
            self._color = 'Orange'
            
    
    @classmethod
    def black_carrot(self):
        return self('Black', 'Bitter')
    #is a class method. It’s not bound to one particular instance of Carrot. 
    #Class methods are often used as factory methods that can create specific instances of the class.
    
    @staticmethod
    def describtion():
        print('A carrot is a vegetable, or more specifically a root')
    #is a static method. It’s not dependent on the class, 
    #Static methods can be called on either an instance or the class.
    
    

culture_carrot = Carrot('Yellow', 'Sweet')
print(culture_carrot.color, culture_carrot.taste)

culture_carrot.color = 47
print(culture_carrot.color)

carrot = Carrot.black_carrot()
print(carrot.color, carrot.taste)


carrot.describtion()
Carrot.describtion()
# Out:
# Yellow Sweet
# That cant possible be a color, so now its just orange now
# Orange
# Black Bitter
# A carrot is a vegetable, ore more specifically a root
# A carrot is a vegetable, ore more specifically a root

# %% [markdown]
# # Blackjack

# %%
# DECK CLASS
import random

class Deck():
    def __init__(self):
        cards = [[(y,x) for x in ['Clubs', 'Diamonds', 'Hearts', 'Spades']] for y in range(1,14)]
        cards =  [x for sublist in cards for x in sublist]
        self.cards = cards    
        
    def __str__(self):
        return(f'deck = {self.cards}')
    
    def __len__(self):
        count = 0
        for x in self.cards:
            count += 1
        return(count)
    
    def __getitem__(self, idx):
        if isinstance(idx, int):
            try:
                return(self.cards[idx])
            except(KeyError):
                print("list index out of range")
        else:
            raise(typeError)
            
    def __setitem__(self, slice_, value):
        print(f'{slice_} this is index input')
        
        try:
            if str(value[1]).lower() in ['clubs', 'diamonds', 'hearts', 'spades']:
                if isinstance(slice_, int):
                    self.cards[slice_] = (value[0], value[1])
                else:
                    self.cards[slice_.start:slice_.stop:slice_.step] = [(value[0], value[1])]       
            else:
                print('color of card must be either clubs, diamonds, hearts, spades')
        except(KeyError):
            print('list index out of range')
                
    def __delitem__(self, idx):
        if isinstance(idx, int):
            try:
                self.cards[idx:idx+1] = []
            except(KeyError):
                print('list index out of range')
                
    def __iter__(self):
        return iter(self.cards)
    
    @staticmethod
    def describtion():
        print('This is a standard 52-card deck of French-suited playing cards. it is the most common pack of playing cards used today')
    #is a static method. It’s not dependent on the class, 
    #Static methods can be called on either an instance or the class.
    
    def pop(self, idx):
        return self.cards.pop(idx)
    
    
    def shuffle(self):
        random.shuffle(self.cards)

# %%
#PARTICIPANT

class Participant():
    
    game_status = 1
    
    def __init__(self, cash = 0, status = 0):
        
        self.hand = [[]]
        self.cash = cash
        self.status = status
        
    def receive_card(self, card, idx):
        self.hand[idx].insert(0, card)
    
    def result(self, amount, game_over = 'Game over'):
        self.cash += amount
        if self.cash == 0:
            self.game_status = game_over
    
    def round_over(self, result):
        self.cash += result

# %%
#PLAYER

class Player(Participant):
    
    bet = [[]]
    
    def __init__(self, dealer):
        super().__init__()
        self.cash = 500
        self.dealer = dealer
    
    def place_bet(self, p_bet = 0, target = 'none', double = 'none'):
        if self.cash - p_bet < 0:
            p_bet = self.cash
            print(f'insufficient funds placed bet of {p_bet} instead')
        if target == 'none':
            self.cash -= p_bet
            self.bet[0] = p_bet
        elif double == 'none':
            self.cash -=  self.bet[target]
            self.bet = [x for i,x in enumerate(self.bet) if i !=target] + [self.bet[target], self.bet[target]]
        else:
            self.cash -= self.bet[target]
            self.bet[target] = self.bet[target] * 2
        print(f'cash : {self.cash}')
                
    def result(self, amount, game_over = 'Game over player broke'):
        return super().result(amount, game_over)
    
    def hit(self, idx):
        self.dealer.deal(idx, 1)
        
    def split(self,target):
        self.hand = [x for i,x in enumerate(self.hand) if i!=target] + [[x] for x in self.hand[target]]
        
    def receive_card(self, card, idx):
        super().receive_card(card, idx)
        if len(self.hand) == 1 and all(len(x) >= 2 for x in self.hand):
            print(f'Player hand: {self.hand}')
        elif all(len(x) >= 2 for x in self.hand):
            for i, y in enumerate(self.hand):
                print(f'Player hand number {i}: {y}')

# %%
#DEALER

class Dealer(Participant):
    
    d_h_sum = 0
    
    def __init__(self, deck):
        super().__init__()
        self.cash = 100000
        self.player = None
        self.deck = deck
      
    @property
    def d_h_sum(self):
        return self.__d_h_sum
    
    @d_h_sum.setter
    def d_h_sum(self, inp):
        if isinstance(inp, int):
            self.__d_h_sum = inp
        
    
    def __draw(self):
        try:
            return self.deck.pop(0)
        except IndexError:
            print('No more cards in deck, new deck was inserted in shoe')
            self.deck = Deck()
            self.deck.shuffle()
            return self.deck.pop(0)
            
    
    def __deal_player_card(self, card, idx):
        self.player.receive_card(card, idx) 
        
    
    def deal(self, idx, target = 0):
        card = self.__draw()
        if target == 0: 
            self.__receive_card(card)
        else:
            self.__deal_player_card(card, idx)
    
    def add_player(self, player):
        self.player = player
    
    def result(self, amount, game_over = 'Congratulazions you beat the house, the game is over!'):
        return super().result(amount, game_over)
    
    def round_over(self, bets):
        for i in bets:
            if i[1] == 0:#draw
                self.player.result(i[0])
            if i[1] == 1:#dealer blackjack
                self.result(i[0])
                self.player.result(0)
            if i[1] == 2:#player blackjack
                self.player.result(i[0] + i[0]*1.5)
                self.result(-(i[0] * 1.5))
            if i[1] == 3:#player won
                self.player.result(i[0]*2)
                self.result(-i[0])
    
    def __receive_card(self, card):
        super().receive_card(card, 0)
        if len(self.hand[0]) == 2:
            print(f'Dealer hand: [{self.hand[0][0]}, [x, xxxxx]]')
            
        
    def evaluate(self, a_hand):
        
        self.d_h_sum = self.__count_sum(self.hand[0])
        p_h_sum = self.__count_sum(a_hand)
            
        
        if(self.status == 5):
            
            if (len(self.hand[0]) == 2 and (self.hand[0][0][0] == 1 or self.hand[0][1][0] == 1) and
                                        (self.hand[0][0][0] >= 10 or self.hand[0][1][0] >= 10)):
            
                if (len(a_hand) == 2 and (a_hand[0][0] == 1 or a_hand[1][0] == 1) and 
                                        (a_hand[0][0] >= 10 or a_hand[1][0] >= 10)):
                    print('----------------DRAW! PLAYER AND DEALER BLACKJACK-----------------')
                    return 0
                else:
                    print('------------------------DEALER BLACKJACK!-------------------------')
                    return 1
            if len(a_hand) == 2 and (a_hand[0][0] == 1 or a_hand[1][0] == 1) and (a_hand[0][0] >= 10 or a_hand[1][0] >= 10):
                print('------------------------PLAYER BLACKJACK!-------------------------')
                return 2
            
            if(self.d_h_sum > 21 and p_h_sum > 21):
                print('----------------DEALER WON! PLAYER AND DEALER BUST-----------------')
                return 1
            elif(self.d_h_sum > 21):
                print('-----------------------PLAYER WON, DEALER BUST!-------------------------')
                return 3
            elif(p_h_sum > 21):
                print('-----------------------DEALER WON, PLAYER BUST!-------------------------')
                return 1
        
            if p_h_sum > self.d_h_sum and p_h_sum <= 21:
                print('---------------------------PLAYER WON!----------------------------')
                return 3
            elif p_h_sum == self.d_h_sum:
                print('----------------DRAW! PLAYER AND DEALER SAME VALUE-----------------')
                return 0
            else:
                print('---------------------------DEALER WON!----------------------------') 
                return 1
            
        elif p_h_sum >= 21:
            return 7
            
        return 6
    
    def __count_sum(self, hand): 
        hand_sum = 0
        aces = 0
        for i in hand:
            if(i[0] == 1):
                aces += 1  
                continue
            elif(i[0] >= 10):
                hand_sum += 10
                continue
            hand_sum += i[0]
        for i in range(aces):
            if hand_sum + 11 > 21:
                hand_sum += 1
            else:
                hand_sum += 11
        return(hand_sum)

# %%
# UTILITY FUNCTIONS

def user_input(string = None, integer = False, legals = None):
    while True:
        if integer != False:
            try:   
                return int(input())
            except ValueError:
                print('Insert valid integer amount')
        else:
            temp = str(input(string)).lower()
            temp.lower()
            if temp in legals:
                return temp
            else:
                print(f'You cant do that, your legal actions are {legals}')

# %%
# about, rules, strategy
import requests
from bs4 import BeautifulSoup
import functools
import webbrowser


def display_strategy_table():
    webbrowser.open('https://www.blackjackapprenticeship.com/wp-content/uploads/2018/08/BJA_Basic_Strategy.jpg')
    

def load_info_from_web():
    response = requests.get('http://www.hitorstand.net/strategy.php').text
    soup = BeautifulSoup(response, features = 'lxml')

    with open('Black_jack_info.txt', 'w') as f:
        f.write(' <intro> '+soup.p.text+' <intro> '+ ' <h2> '+soup.h1.text+' <h2> ' + ' <rules> '+soup.ul.text+' <rules> ')



def word_for_word_generator():
    with open('Black_jack_info.txt','r') as f:
        for line in f:
            for word in line.split():
                yield(word) 
                

def reader(flag, information, inf_dict):
    count = 0
    paragraph = ''
    flag_word = False
    if flag in inf_dict:
        print('--------------------------------------------------------------')
        print(inf_dict[flag])
    else:
        for word in information:
            if word.startswith('<') and word.endswith('>') and word != flag_word:
                flag_word = word
            elif word == flag_word:
                inf_dict[word] = paragraph
                flag_word = False
                paragraph = ''
            
            if information != None:
                if flag == word:
                    count +=1
                    if count == 2:
                        print('--------------------------------------------------------------')
                        print(inf_dict[flag])
                        break
                elif not word.startswith('<') and not word.endswith('>'):
                    paragraph += word+' '
                    if word.endswith('.'):
                        paragraph += '\n'
        

def start_decor(func):
    @functools.wraps(func)
    def wrapper(*args, **kwargs):
        print('This is a game of Blackjack that I have designed, rules are the standard rules, without any add-ons')
        func(*args, **kwargs)
    return wrapper

                
    
@start_decor
def rules_and_info(information, inf_dict):
    while True:
        inp = str(input('To start game type hit enter, for introduction type "intro", for rules type "rules" for strategy type "strategy" ')).lower()
        if inp == 'intro':
            reader('<intro>', information, inf_dict)
        elif inp == 'rules':
            reader('<h2>', information,inf_dict)
            reader('<rules>', information, inf_dict)
        elif inp == '':
            break
        elif inp == 'strategy':
            display_strategy_table()

# %%
#GAME LOOP

def game_loop():
    
    #Load data to file from website
    load_info_from_web()   
    #create generator
    info = word_for_word_generator()
    info_dict = {}#dict for storing info
    
    rules_and_info(info, info_dict)
    
    while True:
        
        deck = Deck()
        dealer = Dealer(deck = deck)
        player = Player(dealer)
        dealer.add_player(player)
        deck.shuffle() 

        while(dealer.game_status == 1 and player.game_status == 1):
            player.hand = [[]]
            dealer.hand = [[]]
            player.bet = [[]]
        
            print('New Round!')
            print(f'Player place your bet!, your balance is {player.cash}')
            player.place_bet(user_input(integer = True))
    
            dealer.deal(target=1, idx=0)
            dealer.deal(target=0, idx=0)
            dealer.deal(target=1, idx=0)
            dealer.deal(target=0, idx=0)

        
            control_idx = 0
             
            while (control_idx+1) <= len(player.hand):
                print('------------------------------------------------------------------')
                
                status = dealer.evaluate(player.hand[control_idx])
                if status == 7:
                    print(f'status: {status}')
                    control_idx += 1
                    continue
                    
                if len(player.hand) >= 2:
                    print(f'You are currently playing on this hand: {player.hand[control_idx]}')
                    
                
            
                if (len(player.hand[control_idx]) == 2 and player.hand[control_idx][0][0] == player.hand[control_idx][1][0]
                                                                               and player.bet[control_idx] <= player.cash): 
                    player_decision = user_input(string='player make your move, you can hit,stand,double or split!',legals=['hit','stand','double','split'])
                    if player_decision == 'split':
                        player.split(0)
                        player.place_bet(target=control_idx)
                        player.hit(-1)
                        player.hit(-2)
                        continue
                        
                    if player_decision == 'double':
                        player.place_bet(target=control_idx, double = True)
                        player.hit(control_idx)
                        control_idx += 1
                        continue
                            
                elif len(player.hand[control_idx]) == 2 and player.bet[control_idx] <= player.cash:
                    player_decision = user_input(string='Player make your move, you can hit,stand or double!', legals=['hit', 'stand', 'double'])
                    if player_decision == 'double':
                        player.place_bet(target=control_idx, double = True)
                        player.hit(control_idx)
                        control_idx += 1
                        continue
                
                else:
                    player_decision = user_input(string='Player make your move, you can hit or stand!', legals=['hit', 'stand'])
                    
                if player_decision == 'hit':
                    player.hit(control_idx)
                    status = dealer.evaluate(player.hand[control_idx])
                    if status == 7:
                        control_idx += 1
                    continue
                if player_decision == 'stand':
                    control_idx += 1
                    continue
            
            if len(player.hand) < control_idx +1:
                while(dealer.d_h_sum < 17):
                    dealer.deal(0)
                    dealer.d_h_sum = dealer._Dealer__count_sum(dealer.hand[0])
                else:
                    print(f'DEALER FINAL HAND: {dealer.hand}')
                
                dealer.status = 5
                for i in range(len(player.hand)):
                    status = dealer.evaluate(player.hand[i])
                    player.bet[i] = (player.bet[i], status)
                control_idx = len(player.hand) -1
            
                
            
            dealer.status = 6 #hand played
        
            dealer.round_over(player.bet)
            dealer.status = 6
            control_idx = 0
            
            if dealer.game_status != 1:
                print(dealer.game_status)
            elif player.game_status != 1:
                print(player.game_status)
        while True:
            inp = str(input('Play agian, "yes" or "no" ')).lower()
            if inp == 'yes':
                break
            if inp == 'no':
                break
        if inp == 'no':
            break

# %%
game_loop()
# Out:
# This is a game of Blackjack that I have designed, rules are the standard rules, without any add-ons
# To start game type hit enter, for introduction type "intro", for rules type "rules" for strategy type "strategy" strategy
# To start game type hit enter, for introduction type "intro", for rules type "rules" for strategy type "strategy"
# New Round!
# Player place your bet!, your balance is 500
# 100
# cash : 400
# Player hand: [[(6, 'Clubs'), (9, 'Spades')]]
# Dealer hand: [(12, 'Clubs'), [x, xxxxx]]
# ------------------------------------------------------------------
# Player make your move, you can hit,stand or double!10
# You cant do that, your legal actions are ['hit', 'stand', 'double']
# Player make your move, you can hit,stand or double!hit
# Player hand: [[(11, 'Clubs'), (6, 'Clubs'), (9, 'Spades')]]
# DEALER FINAL HAND: [[(12, 'Clubs'), (7, 'Hearts')]]
# -----------------------DEALER WON, PLAYER BUST!-------------------------
# New Round!
# Player place your bet!, your balance is 400
# 10
# cash : 390
# Player hand: [[(13, 'Clubs'), (8, 'Hearts')]]
# Dealer hand: [(1, 'Clubs'), [x, xxxxx]]
# ------------------------------------------------------------------
# Player make your move, you can hit,stand or double!stand
# DEALER FINAL HAND: [[(7, 'Diamonds'), (10, 'Hearts'), (1, 'Clubs'), (4, 'Diamonds')]]
# -----------------------PLAYER WON, DEALER BUST!-------------------------
# New Round!
# Player place your bet!, your balance is 410
# 1
# cash : 409
# Player hand: [[(4, 'Spades'), (5, 'Spades')]]
# Dealer hand: [(6, 'Diamonds'), [x, xxxxx]]
# ------------------------------------------------------------------
# Player make your move, you can hit,stand or double!stand
# DEALER FINAL HAND: [[(8, 'Diamonds'), (6, 'Diamonds'), (12, 'Spades')]]
# -----------------------PLAYER WON, DEALER BUST!-------------------------
# New Round!
# Player place your bet!, your balance is 411
# 1
# cash : 410
# Player hand: [[(2, 'Spades'), (12, 'Hearts')]]
# Dealer hand: [(8, 'Spades'), [x, xxxxx]]
# ------------------------------------------------------------------
# Player make your move, you can hit,stand or double!stand
# DEALER FINAL HAND: [[(2, 'Hearts'), (8, 'Spades'), (7, 'Clubs')]]
# ---------------------------DEALER WON!----------------------------
# New Round!
# Player place your bet!, your balance is 410
# 1
# cash : 409
# Player hand: [[(6, 'Hearts'), (4, 'Clubs')]]
# Dealer hand: [(5, 'Diamonds'), [x, xxxxx]]
# ------------------------------------------------------------------
# Player make your move, you can hit,stand or double!stand
# DEALER FINAL HAND: [[(13, 'Diamonds'), (5, 'Diamonds'), (4, 'Hearts')]]
# ---------------------------DEALER WON!----------------------------
# New Round!
# Player place your bet!, your balance is 409
# 1
# cash : 408
# Player hand: [[(6, 'Spades'), (10, 'Spades')]]
# Dealer hand: [(5, 'Clubs'), [x, xxxxx]]
# ------------------------------------------------------------------
# Player make your move, you can hit,stand or double!stand
# DEALER FINAL HAND: [[(13, 'Spades'), (5, 'Clubs'), (7, 'Spades')]]
# -----------------------PLAYER WON, DEALER BUST!-------------------------
# New Round!
# Player place your bet!, your balance is 410
# 1
# cash : 409
# Player hand: [[(10, 'Clubs'), (1, 'Diamonds')]]
# Dealer hand: [(3, 'Diamonds'), [x, xxxxx]]
# ------------------------------------------------------------------
# status: 7
# DEALER FINAL HAND: [[(1, 'Spades'), (1, 'Hearts'), (2, 'Diamonds'), (3, 'Diamonds'), (11, 'Spades')]]
# ------------------------PLAYER BLACKJACK!-------------------------
# New Round!
# Player place your bet!, your balance is 411.5
# 1
# cash : 410.5
# Player hand: [[(9, 'Clubs'), (8, 'Clubs')]]
# Dealer hand: [(3, 'Spades'), [x, xxxxx]]
# ------------------------------------------------------------------
# Player make your move, you can hit,stand or double!stand
# DEALER FINAL HAND: [[(9, 'Diamonds'), (2, 'Clubs'), (3, 'Spades'), (12, 'Diamonds')]]
# -----------------------PLAYER WON, DEALER BUST!-------------------------
# New Round!
# Player place your bet!, your balance is 412.5
# 1
# cash : 411.5
# Player hand: [[(11, 'Diamonds'), (3, 'Hearts')]]
# Dealer hand: [(3, 'Clubs'), [x, xxxxx]]
# ------------------------------------------------------------------
# Player make your move, you can hit,stand or double!stand
# DEALER FINAL HAND: [[(9, 'Hearts'), (3, 'Clubs'), (10, 'Diamonds')]]
# -----------------------PLAYER WON, DEALER BUST!-------------------------
# New Round!
# Player place your bet!, your balance is 413.5
# 1
# cash : 412.5
# Player hand: [[(13, 'Hearts'), (11, 'Hearts')]]
# No more cards in deck, new deck was inserted in shoe
# Dealer hand: [(2, 'Diamonds'), [x, xxxxx]]
# ------------------------------------------------------------------
# Player make your move, you can hit,stand or double!stand
# DEALER FINAL HAND: [[(3, 'Spades'), (8, 'Diamonds'), (2, 'Diamonds'), (5, 'Hearts')]]
# ---------------------------PLAYER WON!----------------------------
# New Round!
# Player place your bet!, your balance is 414.5
# 1
# cash : 413.5
# Player hand: [[(8, 'Spades'), (7, 'Clubs')]]
# Dealer hand: [(10, 'Diamonds'), [x, xxxxx]]
# ------------------------------------------------------------------
# Player make your move, you can hit,stand or double!stand
# DEALER FINAL HAND: [[(10, 'Diamonds'), (11, 'Hearts')]]
# ---------------------------DEALER WON!----------------------------
# New Round!
# Player place your bet!, your balance is 413.5
# 1
# cash : 412.5
# Player hand: [[(11, 'Spades'), (10, 'Hearts')]]
# Dealer hand: [(5, 'Clubs'), [x, xxxxx]]
# ------------------------------------------------------------------
# Player make your move, you can hit,stand or double!stand
# DEALER FINAL HAND: [[(11, 'Diamonds'), (5, 'Clubs'), (11, 'Clubs')]]
# -----------------------PLAYER WON, DEALER BUST!-------------------------
# New Round!
# Player place your bet!, your balance is 414.5
# 1
# cash : 413.5
# Player hand: [[(6, 'Spades'), (2, 'Spades')]]
# Dealer hand: [(9, 'Spades'), [x, xxxxx]]
# ------------------------------------------------------------------
# Player make your move, you can hit,stand or double!stand
# DEALER FINAL HAND: [[(9, 'Spades'), (13, 'Clubs')]]
# ---------------------------DEALER WON!----------------------------
# New Round!
# Player place your bet!, your balance is 413.5
# 1
# cash : 412.5
# Player hand: [[(9, 'Clubs'), (12, 'Hearts')]]
# Dealer hand: [(3, 'Diamonds'), [x, xxxxx]]
# ------------------------------------------------------------------
# Player make your move, you can hit,stand or double!stand
# DEALER FINAL HAND: [[(5, 'Hearts'), (4, 'Diamonds'), (3, 'Diamonds'), (5, 'Spades')]]
# ---------------------------PLAYER WON!----------------------------
# New Round!
# Player place your bet!, your balance is 414.5
# 1
# cash : 413.5
# Player hand: [[(7, 'Spades'), (4, 'Clubs')]]
# Dealer hand: [(3, 'Clubs'), [x, xxxxx]]
# ------------------------------------------------------------------
# Player make your move, you can hit,stand or double!stand
# DEALER FINAL HAND: [[(10, 'Spades'), (6, 'Hearts'), (3, 'Clubs'), (5, 'Diamonds')]]
# -----------------------PLAYER WON, DEALER BUST!-------------------------
# New Round!
# Player place your bet!, your balance is 415.5
# 1
# cash : 414.5
# Player hand: [[(2, 'Clubs'), (9, 'Diamonds')]]
# Dealer hand: [(9, 'Hearts'), [x, xxxxx]]
# ------------------------------------------------------------------
# Player make your move, you can hit,stand or double!stand
# DEALER FINAL HAND: [[(7, 'Diamonds'), (9, 'Hearts'), (6, 'Diamonds')]]
# -----------------------PLAYER WON, DEALER BUST!-------------------------
# New Round!
# Player place your bet!, your balance is 416.5
# 1
# cash : 415.5
# Player hand: [[(6, 'Clubs'), (13, 'Diamonds')]]
# Dealer hand: [(1, 'Spades'), [x, xxxxx]]
# ------------------------------------------------------------------
# Player make your move, you can hit,stand or double!stand
# DEALER FINAL HAND: [[(1, 'Spades'), (8, 'Hearts')]]
# ---------------------------DEALER WON!----------------------------
# New Round!
# Player place your bet!, your balance is 415.5
# 1
# cash : 414.5
# Player hand: [[(3, 'Hearts'), (13, 'Hearts')]]
# Dealer hand: [(7, 'Hearts'), [x, xxxxx]]
# ------------------------------------------------------------------
# Player make your move, you can hit,stand or double!stand
# DEALER FINAL HAND: [[(7, 'Hearts'), (12, 'Spades')]]
# ---------------------------DEALER WON!----------------------------
# New Round!
# Player place your bet!, your balance is 414.5
# 1
# cash : 413.5
# Player hand: [[(4, 'Hearts'), (1, 'Hearts')]]
# Dealer hand: [(1, 'Diamonds'), [x, xxxxx]]
# ------------------------------------------------------------------
# Player make your move, you can hit,stand or double!stand
# DEALER FINAL HAND: [[(1, 'Diamonds'), (12, 'Clubs')]]
# ------------------------DEALER BLACKJACK!-------------------------
# New Round!
# Player place your bet!, your balance is 413.5
# 1
# cash : 412.5
# Player hand: [[(12, 'Diamonds'), (13, 'Spades')]]
# Dealer hand: [(10, 'Clubs'), [x, xxxxx]]
# ------------------------------------------------------------------
# Player make your move, you can hit,stand or double!stand
# DEALER FINAL HAND: [[(8, 'Clubs'), (10, 'Clubs'), (2, 'Hearts')]]
# ----------------DRAW! PLAYER AND DEALER SAME VALUE-----------------
# New Round!
# Player place your bet!, your balance is 413.5
# 1
# cash : 412.5
# No more cards in deck, new deck was inserted in shoe
# Player hand: [[(8, 'Clubs'), (1, 'Clubs')]]
# Dealer hand: [(3, 'Clubs'), [x, xxxxx]]
# ------------------------------------------------------------------
# Player make your move, you can hit,stand or double!stand
# DEALER FINAL HAND: [[(13, 'Hearts'), (3, 'Clubs'), (4, 'Spades')]]
# ---------------------------PLAYER WON!----------------------------
# New Round!
# Player place your bet!, your balance is 414.5
# 1
# cash : 413.5
# Player hand: [[(12, 'Spades'), (5, 'Spades')]]
# Dealer hand: [(13, 'Diamonds'), [x, xxxxx]]
# ------------------------------------------------------------------
# Player make your move, you can hit,stand or double!stand
# DEALER FINAL HAND: [[(10, 'Hearts'), (13, 'Diamonds'), (3, 'Hearts')]]
# -----------------------PLAYER WON, DEALER BUST!-------------------------
# New Round!
# Player place your bet!, your balance is 415.5
# 1
# cash : 414.5
# Player hand: [[(10, 'Clubs'), (2, 'Spades')]]
# Dealer hand: [(9, 'Diamonds'), [x, xxxxx]]
# ------------------------------------------------------------------
# Player make your move, you can hit,stand or double!stand
# DEALER FINAL HAND: [[(12, 'Diamonds'), (9, 'Diamonds'), (5, 'Diamonds')]]
# -----------------------PLAYER WON, DEALER BUST!-------------------------
# New Round!
# Player place your bet!, your balance is 416.5
# 1
# cash : 415.5
# Player hand: [[(12, 'Hearts'), (11, 'Spades')]]
# Dealer hand: [(10, 'Spades'), [x, xxxxx]]
# ------------------------------------------------------------------
# Player make your move, you can hit,stand or double!stand
# DEALER FINAL HAND: [[(10, 'Spades'), (10, 'Diamonds')]]
# ----------------DRAW! PLAYER AND DEALER SAME VALUE-----------------
# New Round!
# Player place your bet!, your balance is 416.5
# 1
# cash : 415.5
# Player hand: [[(1, 'Hearts'), (11, 'Diamonds')]]
# Dealer hand: [(6, 'Hearts'), [x, xxxxx]]
# ------------------------------------------------------------------
# status: 7
# DEALER FINAL HAND: [[(4, 'Clubs'), (6, 'Hearts'), (9, 'Clubs')]]
# ------------------------PLAYER BLACKJACK!-------------------------
# New Round!
# Player place your bet!, your balance is 418.0
# 1
# cash : 417.0
# Player hand: [[(9, 'Hearts'), (11, 'Clubs')]]
# Dealer hand: [(2, 'Hearts'), [x, xxxxx]]
# ------------------------------------------------------------------
# Player make your move, you can hit,stand or double!stand
# DEALER FINAL HAND: [[(1, 'Clubs'), (2, 'Hearts'), (7, 'Spades')]]
# ---------------------------DEALER WON!----------------------------
# New Round!
# Player place your bet!, your balance is 417.0
# 1
# cash : 416.0
# Player hand: [[(7, 'Diamonds'), (3, 'Spades')]]
# Dealer hand: [(9, 'Spades'), [x, xxxxx]]
# ------------------------------------------------------------------
# Player make your move, you can hit,stand or double!stand
# DEALER FINAL HAND: [[(9, 'Spades'), (8, 'Diamonds')]]
# ---------------------------DEALER WON!----------------------------
# New Round!
# Player place your bet!, your balance is 416.0
# 1
# cash : 415.0
# Player hand: [[(11, 'Hearts'), (7, 'Hearts')]]
# Dealer hand: [(13, 'Spades'), [x, xxxxx]]
# ------------------------------------------------------------------
# Player make your move, you can hit,stand or double!stand
# DEALER FINAL HAND: [[(13, 'Spades'), (12, 'Clubs')]]
# ---------------------------DEALER WON!----------------------------
# New Round!
# Player place your bet!, your balance is 415.0
# 1
# cash : 414.0
# Player hand: [[(4, 'Diamonds'), (6, 'Clubs')]]
# Dealer hand: [(8, 'Spades'), [x, xxxxx]]
# ------------------------------------------------------------------
# Player make your move, you can hit,stand or double!stand
# DEALER FINAL HAND: [[(8, 'Spades'), (1, 'Diamonds')]]
# ---------------------------DEALER WON!----------------------------
# New Round!
# Player place your bet!, your balance is 414.0
# 1
# cash : 413.0
# Player hand: [[(1, 'Spades'), (8, 'Hearts')]]
# Dealer hand: [(5, 'Hearts'), [x, xxxxx]]
# ------------------------------------------------------------------
# Player make your move, you can hit,stand or double!stand
# DEALER FINAL HAND: [[(13, 'Clubs'), (5, 'Hearts'), (3, 'Diamonds')]]
# ---------------------------PLAYER WON!----------------------------
# New Round!
# Player place your bet!, your balance is 415.0
# 1
# cash : 414.0
# Player hand: [[(2, 'Clubs'), (7, 'Clubs')]]
# Dealer hand: [(4, 'Hearts'), [x, xxxxx]]
# ------------------------------------------------------------------
# Player make your move, you can hit,stand or double!stand
# DEALER FINAL HAND: [[(6, 'Diamonds'), (2, 'Diamonds'), (4, 'Spades'), (4, 'Hearts'), (5, 'Clubs')]]
# ---------------------------DEALER WON!----------------------------
# New Round!
# Player place your bet!, your balance is 414.0
# 1
# cash : 413.0
# No more cards in deck, new deck was inserted in shoe
# Player hand: [[(6, 'Hearts'), (6, 'Spades')]]
# Dealer hand: [(1, 'Spades'), [x, xxxxx]]
# ------------------------------------------------------------------
# player make your move, you can hit,stand,double or split!split
# cash : 412.0
# Player hand number 0: [(10, 'Diamonds'), (6, 'Hearts')]
# Player hand number 1: [(4, 'Clubs'), (6, 'Spades')]
# ------------------------------------------------------------------
# You are currently playing on this hand: [(10, 'Diamonds'), (6, 'Hearts')]
# Player make your move, you can hit,stand or double!stand
# ------------------------------------------------------------------
# You are currently playing on this hand: [(4, 'Clubs'), (6, 'Spades')]
# Player make your move, you can hit,stand or double!double
# cash : 411.0
# Player hand number 0: [(10, 'Diamonds'), (6, 'Hearts')]
# Player hand number 1: [(1, 'Diamonds'), (4, 'Clubs'), (6, 'Spades')]
# DEALER FINAL HAND: [[(1, 'Spades'), (9, 'Diamonds')]]
# ---------------------------DEALER WON!----------------------------
# ---------------------------PLAYER WON!----------------------------
# New Round!
# Player place your bet!, your balance is 415.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-94f5c72bb83e> in <module>
# ----> 1 game_loop()
#
# <ipython-input-16-346d7d2ebab6> in game_loop()
#      26             print('New Round!')
#      27             print(f'Player place your bet!, your balance is {player.cash}')
# ---> 28             player.place_bet(user_input(integer = True))
#      29
#      30             dealer.deal(target=1, idx=0)
#
# <ipython-input-14-20793268723f> in user_input(string, integer, legals)
#       5         if integer != False:
#       6             try:
# ----> 7                 return int(input())
#       8             except ValueError:
#       9                 print('Insert valid integer amount')
#
# ~\Anaconda3\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     861             self._parent_ident,
#     862             self._parent_header,
# --> 863             password=False,
#     864         )
#     865
#
# ~\Anaconda3\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
